# %%
# !pip install gportal
# Out:
# Collecting gportal
#   Downloading gportal-0.4.0-py3-none-any.whl.metadata (3.2 kB)
# Collecting paramiko<4.0.0,>=3.1.0 (from gportal)
#   Downloading paramiko-3.5.1-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: requests<3.0.0,>=2.28.2 in c:\users\ameri\anaconda3\envs\ml\lib\site-packages (from gportal) (2.32.4)
# Collecting bcrypt>=3.2 (from paramiko<4.0.0,>=3.1.0->gportal)
#   Downloading bcrypt-5.0.0-cp39-abi3-win_amd64.whl.metadata (10 kB)
# Collecting cryptography>=3.3 (from paramiko<4.0.0,>=3.1.0->gportal)
#   Downloading cryptography-46.0.3-cp38-abi3-win_amd64.whl.metadata (5.7 kB)
# Collecting pynacl>=1.5 (from paramiko<4.0.0,>=3.1.0->gportal)
#   Downloading pynacl-1.6.1-cp38-abi3-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ameri\anaconda3\envs\ml\lib\site-packages (from requests<3.0.0,>=2.28.2->gportal) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ameri\anaconda3\envs\ml\lib\site-packages (from requests<3.0.0,>=2.28.2->gportal) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ameri\anaconda3\envs\ml\lib\site-packages (from requests<3.0.0,>=2.28.2->gportal) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ameri\anaconda3\envs\ml\lib\site-packages (from requests<3.0.0,>=2.28.2->gportal) (2025.6.15)
# Collecting cffi>=2.0.0 (from cryptography>=3.3->paramiko<4.0.0,>=3.1.0->gportal)
#   Downloading cffi-2.0.0-cp39-cp39-win_amd64.whl.metadata (2.6 kB)
# Requirement already satisfied: typing-extensions>=4.13.2 in c:\users\ameri\anaconda3\envs\ml\lib\site-packages (from cryptography>=3.3->paramiko<4.0.0,>=3.1.0->gportal) (4.13.2)
# Collecting pycparser (from cffi>=2.0.0->cryptography>=3.3->paramiko<4.0.0,>=3.1.0->gportal)
#   Downloading pycparser-2.23-py3-none-any.whl.metadata (993 bytes)
# Downloading gportal-0.4.0-py3-none-any.whl (18 kB)
# Downloading paramiko-3.5.1-py3-none-any.whl (227 kB)
# Downloading bcrypt-5.0.0-cp39-abi3-win_amd64.whl (150 kB)
# Downloading cryptography-46.0.3-cp38-abi3-win_amd64.whl (3.5 MB)
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    -------------------------- ------------- 2.4/3.5 MB 15.0 MB/s eta 0:00:01
#    ---------------------------------------- 3.5/3.5 MB 11.5 MB/s eta 0:00:00
# Downloading cffi-2.0.0-cp39-cp39-win_amd64.whl (182 kB)
# Downloading pynacl-1.6.1-cp38-abi3-win_amd64.whl (238 kB)
# Downloading pycparser-2.23-py3-none-any.whl (118 kB)
# Installing collected packages: pycparser, bcrypt, cffi, pynacl, cryptography, paramiko, gportal
#
#    ---------------------------------------- 0/7 [pycparser]
#    ----------- ---------------------------- 2/7 [cffi]
#    ----------------- ---------------------- 3/7 [pynacl]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------- ----------------- 4/7 [cryptography]
#    ---------------------------- ----------- 5/7 [paramiko]
#    ---------------------------- ----------- 5/7 [paramiko]
#    ---------------------------------- ----- 6/7 [gportal]
#    ---------------------------------------- 7/7 [gportal]
#
# Successfully installed bcrypt-5.0.0 cffi-2.0.0 cryptography-46.0.3 gportal-0.4.0 paramiko-3.5.1 pycparser-2.23 pynacl-1.6.1

# %% [markdown]
# # Inspect the dataset List available in G-Portal

# %%
import gportal

# Get the dictionary of the G-Portal dataset.
# It corresponds to the "spacecraft/sensor" search tree of the Web UI.
datasets = gportal.datasets()

# %%
datasets
# Out:
# {'GCOM-C/SGLI': {'LEVEL1': {'L1A-Visible & Near Infrared, VNR': ['10001000'],
#    'L1A-Visible & Near Infrared, POL': ['10001001'],
#    'L1A-SWI & TIR': ['10001002'],
#    'L1B-Visible & Near Infrared, VNR': ['10001003'],
#    'L1B-Visible & Near Infrared, POL': ['10001004'],
#    'L1B-SWI & TIR': ['10001005']},
#   'LEVEL2': {'Oceanic sphere': {'L2-NWLR ': ['10002000'],
#     'L2-IWPR': ['10002001'],
#     'L2-SST': ['10002002']},
#    'Cryosphere': {'L2-OKID': ['10002003'],
#     'L2-SICE': ['10002005', '10002004'],
#     'L2-SIPR': ['10002076', '10002075'],
#     'L2-SIPR ver.2': ['10002007', '10002006']},
#    'Cryosphere statistics': {'L2 statistics-SICE': ['10002009', '10002008'],
#     'L2 statistics-SIST': ['10002010'],
#     'L2 statistics-SGSL': ['10002011'],
#     'L2 statistics-SALB': ['10002077']},
#    'Land area': {'L2-LTOA': ['10002014', '10002013', '10002012'],
#     'L2-RSRF': ['10002015'],
#     'L2-VGI': ['10002016'],
#     'L2-LAI': ['10002017'],
#     'L2-AGB': ['10002018'],
#     'L2-LST': ['10002019']},
#    'Land area statistics': {'L2 statistics-LTOA': ['10002022',
#      '10002021',
#      '10002020'],
#     'L2 statistics-RSRF': ['10002078',
#      '10002046',
#      '10002045',
#      '10002044',
#      '10002043',
#      '10002042',
#      '10002041',
#      '10002040',
#      '10002039',
#      '10002038',
#      '10002037',
#      '10002036',
#      '10002035',
#      '10002034',
#      '10002033',
#      '10002032',
#      '10002031',
#      '10002030',
#      '10002029',
#      '10002028',
#      '10002027',
#      '10002026',
#      '10002025',
#      '10002024',
#      '10002023'],
#     'L2 statistics-NDVI': ['10002047'],
#     'L2 statistics-EVI': ['10002048'],
#     'L2 statistics-SDI': ['10002049'],
#     'L2 statistics-FPAR': ['10002050'],
#     'L2 statistics-LAI': ['10002051'],
#     'L2 statistics-AGB': ['10002053'],
#     'L2 statistics-VRI': ['10002052'],
#     'L2 statistics-LST': ['10002054']},
#    'Atmosphere': {'L2-CLFG': ['10002056', '10002055'],
#     'L2-CLPR': ['10002058', '10002057'],
#     'L2-ARNP': ['10002079'],
#     'L2-ARNP Ver.2': ['10002060', '10002059'],
#     'L2-ARPL Ver.2': ['10002062', '10002061']},
#    'Atmosphere global': {'L2 global-LCLR': ['10002063'],
#     'L2 global-LTOA': ['10002066', '10002065', '10002064'],
#     'L2 global-CLFG': ['10002068', '10002067'],
#     'L2 global-CLPR': ['10002070', '10002069'],
#     'L2 global-ARNP': ['10002080'],
#     'L2 global-ARNP Ver.2': ['10002072', '10002071'],
#     'L2 global-ARPL Ver.2': ['10002074', '10002073']}},
#   'LEVEL3': {'Oceanic sphere': {'L3-NWLR': ['10003013',
#      '10003012',
#      '10003011',
#      '10003010',
#      '10003009',
#      '10003008',
#      '10003007',
#      '10003006',
#      '10003005',
#      '10003004',
#      '10003003',
#      '10003002',
#      '10003001',
#      '10003000'],
#     'L3-ACP': ['10003017', '10003016', '10003015', '10003014'],
#     'L3-PAR': ['10003019', '10003018'],
#     'L3-CHLA': ['10003021', '10003020'],
#     'L3-TSM': ['10003023', '10003022'],
#     'L3-CDOM': ['10003025', '10003024'],
#     'L3-SST': ['10003027', '10003026']},
#    'Cryosphere': {'L3-SICE': ['10003031', '10003030', '10003029', '10003028'],
#     'L3-SIST': ['10003035', '10003034', '10003033', '10003032'],
#     'L3-SGSL': ['10003039', '10003038', '10003037', '10003036']},
#    'Land area': {'L3-RSRF': ['10003105',
#      '10003104',
#      '10003103',
#      '10003102',
#      '10003101',
#      '10003100',
#      '10003099',
#      '10003098',
#      '10003097',
#      '10003096',
#      '10003095',
#      '10003094',
#      '10003093',
#      '10003092',
#      '10003091',
#      '10003090',
#      '10003089',
#      '10003088',
#      '10003087',
#      '10003086',
#      '10003085',
#      '10003084',
#      '10003083',
#      '10003082',
#      '10003081',
#      '10003080',
#      '10003079',
#      '10003078',
#      '10003077',
#      '10003076',
#      '10003075',
#      '10003074',
#      '10003073',
#      '10003072',
#      '10003071',
#      '10003070',
#      '10003069',
#      '10003068',
#      '10003067',
#      '10003066',
#      '10003065',
#      '10003064',
#      '10003063',
#      '10003062',
#      '10003061',
#      '10003060',
#      '10003059',
#      '10003058',
#      '10003057',
#      '10003056',
#      '10003055',
#      '10003054',
#      '10003053',
#      '10003052',
#      '10003051',
#      '10003050',
#      '10003049',
#      '10003048',
#      '10003047',
#      '10003046',
#      '10003045',
#      '10003044',
#      '10003043',
#      '10003042',
#      '10003041',
#      '10003040'],
#     'L3-NDVI': ['10003107', '10003106'],
#     'L3-EVI': ['10003109', '10003108'],
#     'L3-SDI': ['10003111', '10003110'],
#     'L3-FPAR': ['10003113', '10003112'],
#     'L3-LAI': ['10003115', '10003114'],
#     'L3-AGB': ['10003117', '10003116'],
#     'L3-VRI': ['10003119', '10003118'],
#     'L3-LST': ['10003121', '10003120']},
#    'Atmosphere': {'L3-CLFR': ['10003147',
#      '10003146',
#      '10003145',
#      '10003144',
#      '10003143',
#      '10003142',
#      '10003141',
#      '10003140',
#      '10003139',
#      '10003138',
#      '10003137',
#      '10003136',
#      '10003135',
#      '10003134',
#      '10003133',
#      '10003132',
#      '10003131',
#      '10003130',
#      '10003129',
#      '10003128',
#      '10003127',
#      '10003126',
#      '10003125',
#      '10003124',
#      '10003123',
#      '10003122'],
#     'L3-CLTT': ['10003149', '10003148'],
#     'L3-CLTH': ['10003151', '10003150'],
#     'L3-COTW': ['10003153', '10003152'],
#     'L3-CERW': ['10003155', '10003154'],
#     'L3-COTI': ['10003157', '10003156'],
#     'L3-AROT': ['10003173', '10003172'],
#     'L3-ARAE': ['10003175', '10003174'],
#     'L3-ASSA': ['10003177', '10003176'],
#     'L3-AOTO Ver.2': ['10003159', '10003158'],
#     'L3-AOTL Ver.2': ['10003161', '10003160'],
#     'L3-AAEO Ver.2': ['10003163', '10003162'],
#     'L3-AAEL Ver.2': ['10003165', '10003164'],
#     'L3-AOTP Ver.2': ['10003167', '10003166'],
#     'L3-AAEP Ver.2': ['10003169', '10003168'],
#     'L3-ASSA Ver.2': ['10003171', '10003170']}}},
#  'GCOM-W/AMSR2': {'LEVEL1': {'L1B-Brightness temperature（TB）': ['11001001'],
#    'L1R-Brightness temperature（TB）': ['11001002']},
#   'LEVEL2': {'L2-Integrated Water Vapor（TPW）': ['11002009', '11002000'],
#    'L2-Cloud Liquid Water（CLW）': ['11002010', '11002001'],
#    'L2-Precipitation（PRC）': ['11002003', '11002002'],
#    'L2-Sea Surface Temperture（SST）': ['11002011', '11002004'],
#    'L2-Sea Surface Wind Speed（SSW）': ['11002012', '11002005'],
#    'L2-Sea Ice Concentration（SIC）': ['11002013', '11002006'],
#    'L2-Snow Depth（SND）': ['11002014', '11002007'],
#    'L2-Soil Moisture Content（SMC）': ['11002015', '11002008']},
#   'LEVEL3': {'10km/0.1deg': {'L3-Integrated Water Vapor（TPW）_0.1deg': ['11003001',
#      '11003000'],
#     'L3-Cloud Liquid Water（CLW）_0.1deg': ['11003003', '11003002'],
#     'L3-Precipitation（PRC）_0.1deg': ['11003005', '11003004'],
#     'L3-Sea Surface Temperture（SST）_0.1deg': ['11003007', '11003006'],
#     'L3-Sea Surface Wind Speed（SSW）_0.1deg': ['11003009', '11003008'],
#     'L3-Ice Concentration（SIC）_0.1deg': ['11003011', '11003010'],
#     'L3-Snow Depth（SND）_0.1deg': ['11003013', '11003012'],
#     'L3-Soil Moisture Content（SMC）_0.1deg': ['11003015', '11003014'],
#     'L3-Brightness temperature（TB）_6GHz_0.1deg': ['11003017', '11003016'],
#     'L3-Brightness temperature（TB）_7GHz_0.1deg': ['11003019', '11003018'],
#     'L3-Brightness temperature（TB）_10GHz_0.1deg': ['11003021', '11003020'],
#     'L3-Brightness temperature（TB）_18GHz_0.1deg': ['11003023', '11003022'],
#     'L3-Brightness temperature（TB）_23GHz_0.1deg': ['11003025', '11003024'],
#     'L3-Brightness temperature（TB）_36GHz_0.1deg': ['11003027', '11003026'],
#     'L3-Brightness temperature（TB）_89GHz_0.1deg': ['11003029', '11003028']},
#    '25km/0.25deg': {'L3-Integrated Water Vapor（TPW）_0.25deg': ['11003031',
#      '11003030'],
#     'L3-Cloud Liquid Water（CLW）_0.25deg': ['11003033', '11003032'],
#     'L3-Precipitation（PRC）_0.25deg': ['11003035', '11003034'],
#     'L3-Sea Surface Temperture（SST）_0.25deg': ['11003037', '11003036'],
#     'L3-Sea Surface Wind Speed（SSW）_0.25deg': ['11003039', '11003038'],
#     'L3-Sea Ice Concentration（SIC）_0.25deg': ['11003041', '11003040'],
#     'L3-Snow Depth（SND）_0.25deg': ['11003043', '11003042'],
#     'L3-Soil Moisture Content（SMC）_0.25deg': ['11003045', '11003044'],
#     'L3-Brightness temperature（TB）_6GHz_0.25deg': ['11003047', '11003046'],
#     'L3-Brightness temperature（TB）_7GHz_0.25deg': ['11003049', '11003048'],
#     'L3-Brightness temperature（TB）_10GHz_0.25deg': ['11003051', '11003050'],
#     'L3-Brightness temperature（TB）_18GHz_0.25deg': ['11003053', '11003052'],
#     'L3-Brightness temperature（TB）_23GHz_0.25deg': ['11003055', '11003054'],
#     'L3-Brightness temperature（TB）_36GHz_0.25deg': ['11003057', '11003056'],
#     'L3-Brightness temperature（TB）_89GHz_0.25deg': ['11003059', '11003058']}}},
#  'GPM': {'DPR': {'LEVEL1': {'KuPR L1B Received Power': ['12001000'],
#     'KaPR L1B Received Power': ['12001001']},
#    'LEVEL2': {'KuPR L2 Precipitation': ['12002000'],
#     'KaPR L2 Precipitation': ['12002001'],
#     'DPR L2 Precipitation': ['12002002'],
#     'DPR L2 Spectral Latent Heating': ['12002003']},
#    'LEVEL3': {'DPR L3 Precipitation (Daily HDF)': ['12003000'],
#     'DPR L3 Precipitation (Daily TEXT)': ['12003001'],
#     'DPR L3  Precipitation (Monthly HDF)': ['12003004'],
#     'DPR L3 Gridded Orbital Spectral Latent Heating': ['12003006'],
#     'DPR L3 Monthly Spectral Latent Heating': ['12003007']}},
#   'GMI': {'LEVEL1': {'GMI L1B Brightness Temperature': ['12011000'],
#     'GMI L1C Inter- Calibrated Brightness Temperature': ['12011001']},
#    'LEVEL2': {'GMI L2 Precipitation': ['12012000']},
#    'LEVEL3': {'GMI L3 Precipitation': ['12013000']}},
#   'DPR/GMI（COMB）': {'LEVEL2': {'COMB L2 Precipitation': ['12022000']},
#    'LEVEL3': {'Comb DPR/GMI L3 Precipitation': ['12023000'],
#     'COMB L3 Gridded Orbital Spectral Latent Heating ': ['12023001'],
#     'COMB L3 Monthly Spectral Latent Heating': ['12023002']}},
#   'Environment Auxiliary': {'KuPR Environment Auxiliary': ['12032000'],
#    'KaPR Environment Auxiliary': ['12032001'],
#    'DPR Environment Auxiliary': ['12032002']}},
#  'GPM Constellation satellites': {'TMI': {'LEVEL1': {'TRMM TMI L1C Inter-Calibrated Brightness Temperature': ['13001000']}},
#   'AMSR2': {'LEVEL1': {'GCOM-W AMSR2 L1C Inter-Calibrated Brightness Temperature': ['13011000']}},
#   'SSMIS': {'LEVEL1': {'DMSP F16 SSMIS L1C Inter-Calibrated Brightness Temperature': ['13021000'],
#     'DMSP F17 SSMIS L1C Inter-Calibrated Brightness Temperature': ['13021001'],
#     'DMSP F18 SSMIS L1C Inter-Calibrated Brightness Temperature': ['13021002'],
#     'DMSP F19 SSMIS L1C Inter-Calibrated Brightness Temperature': ['13021003']}},
#   'MHS': {'LEVEL1': {'NOAA-18 MHS L1C Inter-Calibrated Brightness Temperature': ['13031000'],
#     'NOAA-19 MHS L1C Inter-Calibrated Brightness Temperature': ['13031001'],
#     'METOP-A MHS L1C Inter-Calibrated Brightness Temperature': ['13031002'],
#     'METOP-B MHS L1C Inter-Calibrated Brightness Temperature': ['13031003']}},
#   'ATMS': {'LEVEL1': {'NPP ATMS L1C Inter-Calibrated Brightness Temperature': ['13041000']}},
#   'SAPHIR': {'LEVEL1': {'Megha Tropiques SAPHIR L1C Inter-Calibrated Brightness Temperature': ['13051000']}}},
#  'GSMaP': {'LEVEL3': {'GSMaP Precipitation(Hourly HDF)': ['14003000'],
#    'GSMaP Precipitation(Hourly TEXT)': ['14003001'],
#    'GSMaP Precipitation(Monthly HDF)': ['14003004']}},
#  'TRMM_GPMFormat': {'PR': {'LEVEL1': {'PR L1B Received Power': ['15001000']},
#    'LEVEL2': {'PR L2 Precipitation': ['15002000'],
#     'PR L2 Spectral Latent Heating': ['15002001']},
#    'LEVEL3': {'PR L3 Precipitation (Daily HDF)': ['15003000'],
#     'PR L3 Precipitation (Daily TEXT)': ['15003001'],
#     'PR L3 Precipitation (Monthly HDF)': ['15003002'],
#     'PR L3 Gridded Orbital Spectral Latent Heating': ['15003003'],
#     'PR L3 Monthly Spectral Latent Heating': ['15003004']}},
#   'TMI': {'LEVEL1': {'TMI L1B Brightness Temperature': ['15011000']},
#    'LEVEL2': {'TMI L2 Precipitation': ['15012000']},
#    'LEVEL3': {'TMI L3 Precipitation': ['15013000']}},
#   'PR/TMI(COMB)': {'LEVEL2': {'COMB L2 Precipitation': ['15022000']},
#    'LEVEL3': {'COMB L3 Precipitation': ['15023000'],
#     'COMB L3 Gridded Orbital Spectral Latent Heating ': ['15023001'],
#     'COMB L3 Monthly Spectral Latent Heating': ['15023002']}},
#   'VIRS': {'LEVEL1': {'VIRS L1B Radiance': ['15031000']}},
#   'Environment Auxiliary': {'PR Environment Auxiliary': ['15042000']}},
#  'EarthCARE': {'CPR': {'LEVEL1': {'CPR L1b（CPR_NOM）': ['16001000']},
#    'LEVEL2': {'Echo Product（CPR_ECO）': ['16002000'],
#     'Cloud Product（CPR_CLP）': ['16002001'],
#     'Feature Mask and Corrected Reflectivity（CPR_FMR）': ['16002002'],
#     'Corrected CPR Doppler Measurements（CPR_CD_）': ['16002003'],
#     'Target Classification（CPR_TC_）': ['16002004'],
#     'Cloud profiles（CPR_CLD）': ['16002005']}},
#   'ATLID': {'LEVEL1': {'L1b Backscatter Coefficient（ATL_NOM）': ['16011000']},
#    'LEVEL2': {'Cloud and Aerosol（ATL_CLA）': ['16012000'],
#     'Feature Mask（ATL_AF_）': ['16012001'],
#     'Aerosol Profiles（ATL_AER）': ['16012002'],
#     'Extinction, Backscatter, Depolarisation（ATL_EBD）': ['16012003'],
#     'Target Classification（ATL_TC_）': ['16012004'],
#     'Ice Cloud Properties（ATL_ICE）': ['16012005'],
#     'Cloud Top Height（ATL_CTH）': ['16012006'],
#     'Aerosol Layer Descriptor（ATL_ALD）': ['16012007']}},
#   'MSI': {'LEVEL1': {'L1b Radiance（MSI_NOM_1B）': ['16021000'],
#     'L1c Radiance（MSI_RGR_1C）': ['16021001']},
#    'LEVEL2': {'Cloud Product（MSI_CLP）': ['16022000'],
#     'Cloud Mask （MSI_CM_）': ['16022001'],
#     'Cloud Microphysical Parameters（MSI_COP）': ['16022002'],
#     'Aerosol Optical Thickness （MSI_AOT）': ['16022003']}},
#   'BBR': {'LEVEL1': {'L1b Radiometric（BBR_NOM）': ['16031000']}},
#   'CPR+ATLID': {'LEVEL2': {'CPR-ATLID Synergy Cloud（AC__CLP）': ['16042000'],
#     'CPR-ATLID target classification (AC__TC_)': ['16042001']}},
#   'CPR+ATLID+MSI': {'LEVEL2': {'CPR-ATLID-MSI Synergy Cloud（ACM_CLP）': ['16052000'],
#     'Radiative flux and heating rate profiles & TOA (ACM_RT)': ['16052001'],
#     'Cloud and precipitation best estimates（ACM_CAP）': ['16052002'],
#     'Composite cloud /aerosol profiles derived from L2a（ACM_COM）': ['16052003']}},
#   'CPR+ATLID+MSI+BBR': {'LEVEL2': {'Four Sensors Synergy Radiation Budget（ALL_RAD）': ['16062000'],
#     'Difference 1D-Modelled and BBR-Estimated TOA Fluxes（ALL_DF_）': ['16062001'],
#     'Constructed 3D scene indecees（ALL_3D_）': ['16062002']}},
#   'ATLID+MSI': {'LEVEL2': {'Cloud top height（AM__CTH）': ['16072000'],
#     'Aerosol column descriptor（AM__ACD）': ['16072001'],
#     'Merged observations（AM_MO_）': ['16082000']}},
#   'ATLID+MSI+BBR': {'LEVEL2': {'BBR-estimated TOA fluxes (BM__FLX)': ['16082001']}},
#   'BBR+MSI': {'LEVEL2': {'BBR unfiltered radiances（BM__RAD）': ['16092000']}},
#   'Supprt Data': {'L1d Joint Standard Grid (X-JSG)': ['16101000'],
#    'Environment Auxiliary（AUX_2D_）': ['16104000'],
#    'Environment Auxiliary（AUX_3D_）': ['16104001']}},
#  'ALOS': {'ALOS.PRISM': {'Triplet observation mode ': ['26004000'],
#    'Nadir (70km) + Backward (35km)': ['26004001'],
#    'Nadir (70km)': ['26004002'],
#    'Nadir (35km) + Forward (35km)': ['26004003'],
#    'Nadir (35km) + Backward (35km)': ['26004004'],
#    'Forward (35km) + Backward (35km)': ['26004005'],
#    'Nadir (35km)': ['26004006'],
#    'Forward (35km)': ['26004007'],
#    'Backward (35km)': ['26004008']},
#   'ALOS.AVNIR-2': {'Observation': ['26014000']},
#   'ALOS.PALSAR': {'Fine Resolution Mode, Single polarization': ['26024000'],
#    'Fine Resolution Mode, dual polarization': ['26024001'],
#    'Wide Area Observation Mode (Burst mode 1)': ['26024002'],
#    'Wide Area Observation Mode (Burst mode 2)': ['26024003'],
#    'Direct Downlink Mode': ['26024004'],
#    'Polarimetry Mode': ['26024005']}},
#  'ALOS-2': {'ALOS-2.PALSAR-2': {'NA': {'Spotlight SP': ['27004000'],
#     'Ultra-fine[3m] SP': ['27004001'],
#     'Ultra-fine[3m] DP': ['27004002'],
#     'Hight-sensitive[6m] SP': ['27004003'],
#     'Hight-sensitive[6m] DP': ['27004004'],
#     'Hight-sensitive[6m] QP': ['27004005'],
#     'Fine[10m] SP': ['27004006'],
#     'Fine[10m] DP': ['27004007'],
#     'Fine[10m] QP': ['27004008'],
#     'ScanSAR[350㎞](14MHz) SP': ['27004009'],
#     'ScanSAR[350㎞](14MHz) DP': ['27004010'],
#     'ScanSAR[350㎞](28MHz) SP': ['27004011'],
#     'ScanSAR[350㎞](28MHz) DP': ['27004012'],
#     'ScanSAR[490km] SP': ['27004013'],
#     'ScanSAR[490km]DP': ['27004014']}}},
#  'CIRC': {'ALOS-2': {'ALOS-2 CIRC L1 RAD': ['21001000'],
#    'ALOS-2 CIRC LST': ['21001001']}},
#  'ADEOS': {'ADEOS.OCTS': {'L1A.GACVNI': {'GAC Visible and near infrared': ['22001000']},
#    'L1A.GACTI': {'GAC Thermal infrared': ['22001001']},
#    'L1A.RTCVNI': {'RTC Visible and near infrared': ['22001002']},
#    'L1A.RTCTI': {'RTC Thermal infrared': ['22001003']},
#    'L2.GACOC1': {'GAC Ocean Color1': ['22002000']},
#    'L2.GACOC2': {'GAC Ocean Color2': ['22002001']},
#    'L2.GACVI': {'GAC Vegetation Index': ['22002002']},
#    'L2.GACSST': {'GAC Sea Surface Temperatur': ['22002003']},
#    'L2.RTCOC1': {'RTC Ocean Color1': ['22002004']},
#    'L2.RTCOC2': {'RTC Ocean Color2': ['22002005']},
#    'L2.RTCVI': {'RTC Vegetation Index': ['22002006']},
#    'L2.RTCSST': {'RTC Sea Surface Temperatur': ['22002007']},
#    'L3B.GACOC': {'GAC Ocean Color': ['22003000']},
#    'L3B.GACVI': {'GAC Vegetation Index': ['22003001']},
#    'L3B.GACSST': {'GAC SeaSurface Temperatur': ['22003002']},
#    'L3M.RTCOCP': {'RTC Ocean Color-CZCS like pigment concentration': ['22003003']},
#    'L3M.RTCOCC': {'RTC Ocean Color-Chlorophyll-a concentration': ['22003004']},
#    'L3M.RTCOCK': {'RTC Ocean Color-Diffuse attenuation coefficient at 490nm(K490)': ['22003005']},
#    'L3M.RTCSST': {'RTC Sea Surface Temperture': ['22003006']},
#    'L3BM.GACOCL': {'GAC Ocean Color': ['22003007']},
#    'L3BM.GACOCP': {'GAC Ocean Color-CZCS like pigment concentration': ['22003008']},
#    'L3BM.GACOCC': {'GAC Ocean Color-Chlorophyll-a concentration': ['22003009']},
#    'L3BM.GACOCK': {'GAC Ocean Color-Diffuse attenuation coefficient at 490nm(K490)': ['22003010']},
#    'L3BM.GACVI': {'GAC Vegetation Index': ['22003011']},
#    'L3BM.GACSST': {'GAC Sea Surface Temperture': ['22003012']}},
#   'ADEOS.AVNIR': {'L1A MU': ['22011000'],
#    'L1B2 MU': ['22011001'],
#    'L1A PAN': ['22011002'],
#    'L1B2 PAN': ['22011003']}},
#  'ADEOS-II': {'ADEOS-II.AMSR': {'L1A': {'AMSR L1A': ['23001000']},
#    'L1B': {'AMSR L1B': ['23001001']},
#    'L2.WV': {'AMSR L2 Water Vapor': ['23002000']},
#    'L2.CLW': {'AMSR L2 Cloud Liquid Water': ['23002001']},
#    'L2.AP': {'AMSR L2 Amount of Precipitation': ['23002002']},
#    'L2.SSW': {'AMSR L2 Sea Surface Wind Speed': ['23002003']},
#    'L2.SST': {'AMSR L2 Sea Surface Temperture': ['23002004']},
#    'L2.IC': {'AMSR L2 Ice Concentration': ['23002005']},
#    'L2.SM': {'AMSR L2 Soil Moisture': ['23002006']},
#    'L2.SWE': {'AMSR L2 Snow Water Equivalence': ['23002007']},
#    'L3.WV': {'AMSR L3 Water Vapor': ['23003000']},
#    'L3.CLW': {'AMSR L3 Cloud Liquid Water': ['23003001']},
#    'L3.AP': {'AMSR L3 Amount of Precipitation': ['23003002']},
#    'L3.SSW': {'AMSR L3 Sea Surface Wind Speed': ['23003003']},
#    'L3.SST': {'AMSR L3 Sea Surface Temperature': ['23003004']},
#    'L3.IC': {'AMSR L3 Ice Concentration': ['23003005']},
#    'L3.SM': {'AMSR L3 Soil Moisture': ['23003006']},
#    'L3.SWE': {'AMSR L3 Snow Water Equivalence': ['23003007']},
#    'L3.BT': {'AMSR L3 Brightness Temperature': ['23003008']}},
#   'ADEOS-II.GLI-1km': {'L1A.VNIR': {'Visible and near infrared': ['23011000']},
#    'L1A.SWIR': {'Short-wavelength infrared': ['23011001']},
#    'L1A.MTIR': {'Middle and thermal infrared': ['23011002']},
#    'L1B.VNIR': {'Visible and near infrared': ['23011004']},
#    'L1B.SWIR': {'Short-wavelength infrared': ['23011005']},
#    'L1B.MTIR': {'Middle and thermal infrared': ['23011006']},
#    'L1B.SLPT': {' SLPT': ['23011007']},
#    'L2.CLFLG': {'Cloud Flag': ['23012000']},
#    'L2.ARAEO': {'Aerosol Angstrom Exponent': ['23012001']},
#    'L2.AROP0': {'Aerosol Optical Thickness': ['23012002']},
#    'L2.CLFR0': {'Cloud fraction': ['23012003']},
#    'L2.CERWR': {'Cloud Effective Particle Radius of water cloud by reflection method': ['23012004']},
#    'L2.CERIE': {'Cloud Effective Particle Radius of ice cloud by emission method': ['23012005']},
#    'L2.COPWR': {'Cloud Optical Thickness of water cloud by reflection method': ['23012006']},
#    'L2.COPIR': {'Cloud Optical Thickness of ice cloud by reflection method': ['23012007']},
#    'L2.COPIE': {'Cloud Optical Thickness of ice cloud by emission method': ['23012008']},
#    'L2.CTTWR': {'Cloud Top Temperature of water cloud by reflection method': ['23012009']},
#    'L2.CTTIE': {'Cloud Top Temperature of ice cloud by emission method': ['23012010']},
#    'L2.CWPWR': {'Cloud Liquid Water Path of water cloud by reflaction method': ['23012012']},
#    'L2.NLLR0': {'Atmospheric Correction': ['23012013']},
#    'L2.CSLR0': {'In-water Particles': ['23012014']},
#    'L2.STLR0': {'Sea Surface Temperature': ['23012015']},
#    'L2.VGI00': {'Vegetation Index': ['23012016']},
#    'L2.PGCP0': {'Precise Geometric Corrected Parameter': ['23012017']},
#    'L2.ACLC0': {'Atmospheric Corrected Data For Land And Cryosphere': ['23012018']},
#    'L2.SNGI0': {'Snow Property': ['23012019']},
#    'L2A.L2AOA': {'Ocean and Atmosphere': ['23012020']},
#    'L2.CHTWR': {'Cloud Top Height of water cloude by emmission method': ['23012011']},
#    'L2A.L2ALC': {'Land and Cryosphere': ['23012021']},
#    'L3B.ARAEO': {'Aerosol Angstrom Exponent': ['23013000']},
#    'L3B.AROP0': {'Aerosol Optical Thickness': ['23013001']},
#    'L3B.CLFR0': {'Cloud fraction': ['23013002']},
#    'L3B.CERWR': {'Cloud Effective Particle Radius of water cloud by reflection method': ['23013003']},
#    'L3B.CERIE': {'Cloud Effective Particle Radius of ice cloud by emission method': ['23013004']},
#    'L3B.COPWR': {'Cloud Optical Thickness of water cloud by reflection method': ['23013005']},
#    'L3B.COPIR': {'Cloud Optical Thickness of ice  cloud by reflection method': ['23013006']},
#    'L3B.COPIE': {'Cloud Optical Thickness of ice cloud by emission method': ['23013007']},
#    'L3B.CTTWR': {'Cloud Top Temperature of water cloud by reflection method': ['23013008']},
#    'L3B.CTTIE': {'Cloud Top Temperature of ice cloud by emission method': ['23013009']},
#    'L3B.CHTWR': {'Cloud Top Height of water cloude by emmission method': ['23013010']},
#    'L3B.CWPWR': {'Cloud Liquid Water Path of water cloud by reflaction method': ['23013011']},
#    'L3B.NW000': {'Normalized water-leaving radiance': ['23013012']},
#    'L3B.LA000': {'Aerosol': ['23013013']},
#    'L3B.CS000': {'In-water Particles': ['23013014']},
#    'L3B.ST000': {'Sea Surface Temperature': ['23013015']},
#    'L3B.SNWG0': {'Snow grain size retrieved with 865nm band': ['23013016']},
#    'L3B.SNWI0': {'Snow impurities': ['23013017']},
#    'L3B.SNWGS': {'Snow grain size retrieved with 1640nm band ': ['23013018']},
#    'L3B.SNWTS': {'Snow surface temperature': ['23013019']},
#    'L3STAMAP.ARAEO': {'Aerosol Angstrom Exponent': ['23013020']},
#    'L3STAMAP.AROP0': {'Aerosol Optical Thickness': ['23013021']},
#    'L3STAMAP.CLFR0': {'Cloud fraction': ['23013022']},
#    'L3STAMAP.CERWR': {'Cloud Effective Particle Radius of water cloud by reflection method': ['23013023']},
#    'L3STAMAP.CERIE': {'Cloud Effective Particle Radius of ice cloud by emission method': ['23013024']},
#    'L3STAMAP.COPWR': {'Cloud Optical Thickness of water cloud by reflection method': ['23013025']},
#    'L3STAMAP.COPIR': {'Cloud Optical Thickness of ice  cloud by reflection method': ['23013026']},
#    'L3STAMAP.COPIE': {'Cloud Optical Thickness of ice cloud by emission method': ['23013027']},
#    'L3STAMAP.CTTWR': {'Cloud Top Temperature of water cloud by reflection method': ['23013028']},
#    'L3STAMAP.CTTIE': {'Cloud Top Temperature of ice cloud by emission method': ['23013029']},
#    'L3STAMAP.CHTWR': {'Cloud Top Height of water cloude by emmission method': ['23013030']},
#    'L3STAMAP.CWPWR': {'Cloud Liquid Water Path of water cloud by reflaction method': ['23013031']},
#    'L3STAMAP.NW000': {'Normalized water-leaving radiance': ['23013032']},
#    'L3STAMAP.LA000': {'Aerosol': ['23013033']},
#    'L3STAMAP.CHLA0': {'Chlorophyll-a': ['23013034']},
#    'L3STAMAP.SS000': {'Suspended solid weight': ['23013035']},
#    'L3STAMAP.CDOM0': {'Absorption of colored dissolved organic matter': ['23013036']},
#    'L3STAMAP.K4900': {'Attenuation coefficent at 490mm': ['23013037']},
#    'L3STAMAP.STDN0': {'Sea Surface Temperature(day/night separately averaged)': ['23013038']},
#    'L3STAMAP.STALL': {'Sea Surface Temperature(add data averaged)': ['23013039']},
#    'L3STAMAP.VGI00': {'Vegetation index': ['23013040']},
#    'L3STAMAP.SNWG0': {'Snow grain size retrieved with 865nm band': ['23013041']},
#    'L3STAMAP.SNWI0': {'Snow impurities': ['23013042']},
#    'L3STAMAP.SNWGS': {'Snow grain size retrieved with 1640nm band': ['23013043']},
#    'L3STAMAP.SNWTS': {'Snow surface temperature': ['23013044']}},
#   'ADEOS-II.GLI-250m': {'L1A': ['23021000'], 'L1B': ['23021001']}},
#  'AQUA': {'AMSR-E': {'LEVEL1': {'L1B Brightness Temperature': ['24001001']},
#    'LEVEL2': {'L2 Water Vapor (WV)': ['24002000'],
#     'L2 Cloud Liquid Water (CLW)': ['24002001'],
#     'L2 Amount of Precipitation (AP)': ['24002002'],
#     'L2 Sea SurfaceWind Speed (SSW)': ['24002003'],
#     'L2 Sea Surface Temperature (SST)': ['24002004'],
#     'L2 Ice Concentration (IC)': ['24002005'],
#     'L2 Soil Moisture (SM)': ['24002006'],
#     'L2 Snow Water Equivalence (SWE)': ['24002007']},
#    'LEVEL3': {'L3 Water Vapor (WV)': ['24003000'],
#     'L3 Cloud Liquid Water (CLW)': ['24003001'],
#     'L3 Amount of Precipitation (AP)': ['24003002'],
#     'L3 Sea SurfaceWind Speed (SSW)': ['24003003'],
#     'L3 Sea Surface Temperature (SST)': ['24003004'],
#     'L3 Ice Concentration (IC)': ['24003005'],
#     'L3 Soid Moisture (SM)': ['24003006'],
#     'L3 Snow Water Equivalence (SWE)': ['24003007'],
#     'L3 Brightness Temperature 6GHz-V (TB6GHz_V)': ['24003008'],
#     'L3 Brightness Temperature 6GHz-H (TB6GHz_H)': ['24003009'],
#     'L3 Brightness Temperature 10GHz-V (TB10GHz_V)': ['24003010'],
#     'L3 Brightness Temperature 10GHz-H (TB10GHz_H)': ['24003011'],
#     'L3 Brightness Temperature 18GHz-V (TB18GHz_V)': ['24003012'],
#     'L3 Brightness Temperature 18GHz-H (TB18GHz_H)': ['24003013'],
#     'L3 Brightness Temperature 23GHz-V (TB23GHz_V)': ['24003014'],
#     'L3 Brightness Temperature 23GHz-H (TB23GHz_H)': ['24003015'],
#     'L3 Brightness Temperature 36GHz-V (TB36GHz_V)': ['24003016'],
#     'L3 Brightness Temperature 36GHz-H (TB36GHz_H)': ['24003017'],
#     'L3 Brightness Temperature 89GHz-V (TB89GHz_V)': ['24003018'],
#     'L3 Brightness Temperature 89GHz-H (TB89GHz_H)': ['24003019']}},
#   'AMSR-E_AMSR2Format': {'LEVEL1': {'L1B Brightness Temperatures (TB)': ['25001000'],
#     'L1R Brightness Temperatures (TB)': ['25001001']},
#    'LEVEL2': {'L2 Total Precipitable Water (TPW)': ['25002000'],
#     'L2 Cloud Liquid Water (CLW)': ['25002001'],
#     'L2 Precipitation (PRC)': ['25002003', '25002002'],
#     'L2 Sea Surface Wind speed (SSW)': ['25002005'],
#     'L2 Sea Surface Temperature (SST)': ['25002004'],
#     'L2 Sea Ice Concentration (SIC)': ['25002006'],
#     'L2 Soil Moisture Content (SMC)': ['25002007'],
#     'L2 Snow Depth (SND)': ['25002008']},
#    'LEVEL3': {'10km/0.1deg': {'L3 Total Precipitable Water (TPW)(0.1°)': ['25003001',
#       '25003000'],
#      'L3 Cloud Liquid Water (CLW)(0.1°)': ['25003003', '25003002'],
#      'L3 Precipitation (PRC)(0.1°)': ['25003005', '25003004'],
#      'L3 Sea Surface Temperature (SST)(0.1°)': ['25003007', '25003006'],
#      'L3 Sea Surface Wind speed (SSW)(0.1°)': ['25003009', '25003008'],
#      'L3 Sea Ice Concentration (SIC)(0.1°)': ['25003011', '25003010'],
#      'L3 Snow Depth (SND)(0.1°)': ['25003015', '25003014'],
#      'L3 Soil Moisture Content (SMC)(0.1°)': ['25003013', '25003012'],
#      'L3 Brightness Temperatures 6GHz (TB)(0.1°)': ['25003017', '25003016'],
#      'L3 Brightness Temperatures 10GHz (TB)(0.1°)': ['25003019', '25003018'],
#      'L3 Brightness Temperatures 18GHz (TB)(0.1°)': ['25003021', '25003020'],
#      'L3 Brightness Temperatures 23GHz (TB)(0.1°)': ['25003023', '25003022'],
#      'L3 Brightness Temperatures 36GHz (TB)(0.1°)': ['25003025', '25003024'],
#      'L3 Brightness Temperatures 89GHz (TB)(0.1°)': ['25003027', '25003026']},
#     '25km/0.25deg': {'L3 Total Precipitable Water (TPW)(0.25°)': ['25003029',
#       '25003028'],
#      'L3 Cloud Liquid Water (CLW)(0.25°)': ['25003031', '25003030'],
#      'L3 Precipitation (PRC)(0.25°)': ['25003033', '25003032'],
#      'L3 Sea Surface Temperature (SST)(0.25°)': ['25003035', '25003034'],
#      'L3 Sea Surface Wind speed (SSW)(0.25°)': ['25003037', '25003036'],
#      'L3 Sea Ice Concentration (SIC)(0.25°)': ['25003039', '25003038'],
#      'L3 Snow Depth (SND)(0.25°)': ['25003043', '25003042'],
#      'L3 Soil Moisture Content (SMC)(0.25°)': ['25003041', '25003040'],
#      'L3 Brightness Temperatures 6GHz (TB)(0.25°)': ['25003045', '25003044'],
#      'L3 Brightness Temperatures 10GHz (TB)(0.25°)': ['25003047', '25003046'],
#      'L3 Brightness Temperatures 18GHz (TB)(0.25°)': ['25003049', '25003048'],
#      'L3 Brightness Temperatures 23GHz (TB)(0.25°)': ['25003051', '25003050'],
#      'L3 Brightness Temperatures 36GHz (TB)(0.25°)': ['25003053', '25003052'],
#      'L3 Brightness Temperatures 89GHz (TB)(0.25°)': ['25003055',
#       '25003054']}}}},
#  'TRMM': {'PR': {'LEVEL1': {'PR Received Power [1B21]': ['18001000'],
#     'PR Reflectivities [1C21]': ['18001001']},
#    'LEVEL2': {'PR Surface Cross Section [2A21]': ['18002000'],
#     'PR Qualitative [2A23]': ['18002001'],
#     'PR Rainfall Profile [2A25]': ['18002002'],
#     'PR Spectral Latent Heating [2H25]': ['18002003']},
#    'LEVEL3': {'PR Monthly Rainfall [3A25]': ['18003000'],
#     'PR Monthly Surface Rain [3A26]': ['18003001'],
#     'PR Gridded Orbital Spectral Latent Heating [3G25]': ['18003002'],
#     'PR Monthly Spectral Latent Heating [3H25]': ['18003003']}},
#   'TMI': {'LEVEL1': {'TMI Brightness Temperatures [1B11]': ['18011000']},
#    'LEVEL2': {'TMI Rainfall Profile [2A12]': ['18012000']},
#    'LEVEL3': {'TMI Monthly Emisssion [3A11]': ['18013000'],
#     'TMI Monthly Rainfall Profile [3A12]': ['18013001']}},
#   'PR/TMI (COMB)': {'LEVEL2': {'COMB Rain Profile [2B31]': ['18032000'],
#     'COMB Convective Stratiform Heating [2H31]': ['18032001']},
#    'LEVEL3': {'COMB Monthly Rainfall [3B31]': ['18033000'],
#     'TRMM and Other Sensors 3-Hourly Rainfall [342]': ['18033001'],
#     'TRMM and Other Sensors Monthly Rainfall [3B43]': ['18033002'],
#     'COMB Gridded Orbital Convective Stratiform Heating [3G31]': ['18033003',
#      '15023001'],
#     'COMB Monthly Convective Stratiform Heating [3H31]': ['18033004']}},
#   'VIRS': {'LEVEL1': {'VIRS Radiance [1B01]': ['18021000']}}},
#  'JERS-1': {'JERS-1.VNIR': {'VNIR': {'L2': {'VNIR': ['17002000']}}},
#   'JERS-1.SWIR': {'SWIR': {'L2': {'SWIR': ['17012000']}}},
#   'JERS-1.SAR': {'SAR': {'L0': {'SAR（L0)': ['17020000']},
#     'L2.1': {'SAR': ['17022000']}}}},
#  'MOS-1': {'MOS-1.MESSR': {'MOS-1/MESSR': ['19004000']}},
#  'MOS-1b': {'MOS-1b.MESSR': {'MOS-1b/MESSR': ['20004000']}},
#  'NASA-CMR': {'Aqua': {'Level2': {'MODIS/Aqua Sea Surface Temperature L2': ['28002000'],
#     'MODISA_L2_Ocean Color': ['28002001'],
#     'MODIS/Aqua Aerosol 5-Min L2 Swath 3km': ['28002002'],
#     'MODIS/Aqua Aerosol 5-Min L2 Swath 10km': ['28002003'],
#     'MODIS/Aqua Clouds 5-Min L2 Swath 1km and 5km': ['28002004']},
#    'Level3': {'MODIS/Aqua Land Surface Temperature/Emissivity Daily L3 Global 1km SIN Grid V006': ['28003000'],
#     'MODIS/Aqua Land Surface Temperature/Emissivity 8-Day L3 Global 1km SIN Grid V006': ['28003001'],
#     'MODIS/Aqua Land Surface Temperature/Emissivity Daily L3 Global 0.05Deg CMG V006': ['28003002'],
#     'MODIS/Aqua Land Surface Temperature/Emissivity 8-Day L3 Global 0.05Deg CMG V006': ['28003003'],
#     'MODIS/Aqua Land Surface Temperature/Emissivity Monthly L3 Global 0.05Deg CMG V006': ['28003004'],
#     'MODIS/Aqua Vegetation Indices 16-Day L3 Global 500m SIN Grid V006': ['28003005'],
#     'MODIS/Aqua Vegetation Indices 16-Day L3 Global 1km SIN Grid V006': ['28003006'],
#     'MODIS/Aqua Vegetation Indices Monthly L3 Global 1km SIN Grid V006': ['28003007'],
#     'MODIS/Aqua Vegetation Indices 16-Day L3 Global 0.05Deg CMG V006': ['28003008'],
#     'MODIS/Aqua Vegetation Indices Monthly L3 Global 0.05Deg CMG V006': ['28003009'],
#     'MODIS/Aqua Vegetation Indices 16-Day L3 Global 250m SIN Grid V006': ['28003010'],
#     'MODIS/Aqua Sea Surface Temperature L3 Monthly': ['28003011'],
#     'MODISA_L3m_Chlorophyll-a': ['28003012'],
#     'MODIS/Aqua Aerosol Cloud Water Vapor Ozone Daily L3 Global 1Deg CMG': ['28003013'],
#     'MODIS/Aqua Aerosol Cloud Water Vapor Ozone 8-Day L3 Global 1Deg CMG': ['28003014'],
#     'MODIS/Aqua Aerosol Cloud Water Vapor Ozone Monthly L3 Global 1Deg CMG': ['28003015'],
#     'MODIS/Aqua Snow Cover Daily L3 Global 0.05Deg CMG V005': ['28003016'],
#     'MODIS/Aqua Snow Cover 8-Day L3 Global 0.05Deg CMG V005': ['28003017']}},
#   'Terra': {'Level2': {'MODIST_L2_SST': ['29002000'],
#     'MODIST_L2_OC': ['29002001'],
#     'MODIS/Terra Aerosol 5-Min L2 Swath 3km': ['29002002'],
#     'MODIS/Terra Aerosol 5-Min L2 Swath 10km': ['29002003'],
#     'MODIS/Terra Clouds 5-Min L2 Swath 1km and 5km': ['29002004']},
#    'Level3': {'MODIS/Terra Land Surface Temperature/Emissivity Daily L3 Global 1km SIN Grid V006': ['29003000'],
#     'MODIS/Terra Land Surface Temperature/Emissivity 8-Day L3 Global 1km SIN Grid V006': ['29003001'],
#     'MODIS/Terra Land Surface Temperature/Emissivity Daily L3 Global 0.05Deg CMG V006': ['29003002'],
#     'MODIS/Terra Land Surface Temperature/Emissivity 8-Day L3 Global 0.05Deg CMG V006': ['29003003'],
#     'MODIS/Terra Land Surface Temperature/Emissivity Monthly L3 Global 0.05Deg CMG V006': ['29003004'],
#     'MODIS/Terra Vegetation Indices 16-Day L3 Global 500m SIN Grid V006': ['29003005'],
#     'MODIS/Terra Vegetation Indices 16-Day L3 Global 1km SIN Grid V006': ['29003006'],
#     'MODIS/Terra Vegetation Indices Monthly L3 Global 1km SIN Grid V006': ['29003007'],
#     'MODIS/Terra Vegetation Indices 16-Day L3 Global 0.05Deg CMG V006': ['29003008'],
#     'MODIS/Terra Vegetation Indices Monthly L3 Global 0.05Deg CMG V006': ['29003009'],
#     'MODIS/Terra Vegetation Indices 16-Day L3 Global 250m SIN Grid V006': ['29003010'],
#     'MODIST_L3m_SST': ['29003011'],
#     'MODIST_L3m_CHL': ['29003012'],
#     'MODIS/Terra Aerosol Cloud Water Vapor Ozone Daily L3 Global 1Deg CMG': ['29003013'],
#     'MODIS/Terra Aerosol Cloud Water Vapor Ozone 8-Day L3 Global 1Deg CMG': ['29003014'],
#     'MODIS/Terra Aerosol Cloud Water Vapor Ozone Monthly L3 Global 1Deg CMG': ['29003015'],
#     'MODIS/Terra Snow Cover Daily L3 Global 0.05Deg CMG V005': ['29003016'],
#     'MODIS/Terra Snow Cover 8-Day L3 Global 0.05Deg CMG V005': ['29003017']}}},
#  'SLATS': {'SHIROP': {'Panchromatic Image': ['30000000']}},
#  'GOSAT-GW/AMSR3': {'LEVEL1': {'L1B - Brightness Temperature (TBB)': ['31001001'],
#    'L1R - Resampled Brightness Temperature (TBR)': ['31001002']},
#   'LEVEL2': {'L2 - Total Precipitable Water （TPW）': ['31002000'],
#    'L2 - Cloud Liquid Water Content（CLW）': ['31002001'],
#    'L2 - Precipitation （PRC）': ['31002002'],
#    'L2 - Sea Surface Temperature （SST）': ['31002003'],
#    'L2 - Sea Surface Wind Speed （SSW）': ['31002004'],
#    'L2 - All-weather Sea Surface Wind Speed（ASW）': ['31002005'],
#    'L2 - Sea Ice Concentration （SIC）': ['31002006'],
#    'L2 - High-resolution Sea Ice Concentration（HSI）': ['31002007'],
#    'L2 - Soil Moisture Content （SMC）': ['31002008'],
#    'L2 - Snow Depth （SND）': ['31002009']},
#   'LEVEL3': {'L3 - Brightness temperature 6.925GHz (TL1)': ['31003000'],
#    'L3 - Brightness temperature 7.3GHz (TL2)': ['31003001'],
#    'L3 - Brightness temperature 10.25GHz (TL3)': ['31003002'],
#    'L3 - Brightness temperature 10.65GHz (TL4)': ['31003003'],
#    'L3 - Brightness temperature 18.7GHz (TL5)': ['31003004'],
#    'L3 - Brightness temperature 23.8GH (TL6)': ['31003005'],
#    'L3 - Brightness temperature 36.42GHz (TL7)': ['31003006'],
#    'L3 - Brightness temperature 89.0GHz (TH1)': ['31003007'],
#    'L3 - Brightness temperature 165.5GHz (TH2)': ['31003008'],
#    'L3 - Brightness temperature 183.31+/-3GHz (TH3)': ['31003009'],
#    'L3 - Brightness temperature 183.31+/-7GHz (TH4)': ['31003010'],
#    'L3 - Total Precipitable Water （TPW）': ['31003011'],
#    'L3 - Cloud Liquid Water Content （CLW）': ['31003012'],
#    'L3 - Precipitation （PRC）': ['31003013'],
#    'L3 - Sea Surface Temperature （SST）': ['31003014'],
#    'L3 - Sea Surface Wind Speed （SSW）': ['31003015'],
#    'L3 - All-weather Sea Surface Wind Speed（ASW）': ['31003016'],
#    'L3 - Sea Ice Concentration （SIC）': ['31003017'],
#    'L3 - High-resolution Sea Ice Concentration（HSI）': ['31003018'],
#    'L3 - Soil Moisture Content （SMC）': ['31003019'],
#    'L3 - Snow Depth （SND）': ['31003020']}}}

# %% [markdown]
# ### Found same precipitation dataset as in JAXA API:

# %%
{'GSMaP': {'LEVEL3': {'GSMaP Precipitation(Hourly HDF)': ['14003000'],
   'GSMaP Precipitation(Hourly TEXT)': ['14003001'],
   'GSMaP Precipitation(Monthly HDF)': ['14003004']}},}

# %% [markdown]
# Specify dataset to be downloaded:

# %%
res = gportal.search(
    dataset_ids=datasets["GSMaP"]["LEVEL3"]["GSMaP Precipitation(Hourly HDF)"],
    start_time="2024-05-01T00:00:00",
    end_time="2024-05-31T23:59:59",
    bbox=[-180, -90, 180, 90],
    params={
        # You can add more parameters.
        # See Appendix 7 of G-Portal User's Manual for more details:
        # https://gportal.jaxa.jp/gpr/assets/mng_upload/COMMON/upload/GPortalUserManual_en.pdf
    },
)

print(f"Will download {res.matched()} files.")
products = res.products()

# %% [markdown]
# Initiate download, will be saved as multiple (as many as indivdual matches were found) .h5 files.
# For the below step, a legitimate username and password need to be provided.
# Unfortunately, the download does not work on windows, however, I got it to work in Colab.

# %%
gportal.username = ""  
gportal.password = ""
gportal.download(products, local_dir=".\data")
